# %%
import os
import torch

import scanpy as sc
import numpy as np
import pandas as pd
import gseapy as gp

from tqdm import tqdm
from sklearn.cluster import KMeans
from contrastive_vi.model.contrastive_vi import ContrastiveVIModel
from scripts import constants
from scvi._settings import settings
# Out:
# Global seed set to 0
# During startup - Warning messages:
# 1: package ‘methods’ was built under R version 3.6.1
# 2: package ‘datasets’ was built under R version 3.6.1
# 3: package ‘utils’ was built under R version 3.6.1
# 4: package ‘grDevices’ was built under R version 3.6.1
# 5: package ‘graphics’ was built under R version 3.6.1
# 6: package ‘stats’ was built under R version 3.6.1

# %%
settings.seed = 0
device = "cpu"
dataset = "zheng_2017"
# Out:
# Global seed set to 0

# %%
split_key = constants.DATASET_SPLIT_LOOKUP[dataset]["split_key"]
background_value = constants.DATASET_SPLIT_LOOKUP[dataset]["background_value"]
seeds = constants.DEFAULT_SEEDS
latent_size = 10

# %%
adata = sc.read_h5ad(
    os.path.join(
        constants.DEFAULT_DATA_PATH,
        f"{dataset}/preprocessed/adata_top_2000_genes.h5ad",
    )
)
ContrastiveVIModel.setup_anndata(adata, layer="count")
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["count"]
# INFO     Successfully registered anndata object containing 16856 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %%
target_indices = np.where(adata.obs[split_key] != background_value)[0]
target_adata = adata[target_indices]

# %%
genes = pd.read_table(
    os.path.join(
        constants.DEFAULT_DATA_PATH,
        dataset,
        "aml027_post_transplant_filtered_gene_bc_matrices",
        "filtered_matrices_mex/hg19",
        "genes.tsv",
    ),
    header=None,
)
genes = genes.rename(columns={0: "ensembl_id", 1: "gene_symbol"})
genes = genes[genes["ensembl_id"].isin(adata.var.index)]

# %%
model_list = []
latent_rep_list = []
for seed in tqdm(seeds):
    result_dir = os.path.join(
        "/projects/leelab/contrastiveVI/results-fixed-background-size",
        f"{dataset}/contrastiveVI/latent_{latent_size}",
        f"{seed}",
    )
    model_list.append(
        torch.load(
            os.path.join(result_dir, "model.ckpt"),
            map_location=device,
        ),
    )
    latent_rep_list.append(
        np.load(os.path.join(result_dir, "latent_representations.npy")),
    )
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [01:50<00:00, 22.10s/it]

# %%
de_result_list = []
for seed_index, seed in enumerate(seeds):
    model = model_list[seed_index]
    latent_rep = latent_rep_list[seed_index]
    latent_clusters = KMeans(n_clusters=2, random_state=123).fit(latent_rep).labels_
    cluster_label = f"cluster_{seed}"
    
    tmp_target_adata = target_adata.copy()
    tmp_target_adata.obs[cluster_label] = latent_clusters.astype(str)
    
    de_result = model.differential_expression(
        adata=tmp_target_adata,
        groupby=cluster_label,
        group1="0",
        group2="1",
        idx1=None,
        idx2=None,
        mode="change",
        delta=0.25,
        batch_size=128,
        all_stats=True,
        batch_correction=False,
        batchid1=None,
        batchid2=None,
        fdr_target=0.05,
        silent=False,
    )
    
    de_result.reset_index()
    de_result["ensembl_id"] = de_result.index
    de_result = de_result.merge(genes, on="ensembl_id")
    de_result["seed"] = seed
    de_result_list.append(de_result)
# Out:
# DE...: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [04:28<00:00, 268.33s/it]
# DE...: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [04:36<00:00, 276.94s/it]
# DE...: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [04:09<00:00, 249.31s/it]
# DE...: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [03:53<00:00, 233.70s/it]
# DE...: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [04:03<00:00, 243.24s/it]

# %%
de_result = pd.concat(de_result_list)

# %%
de_result_mean = (
    de_result.groupby("gene_symbol", as_index=False)
    .mean()
    .sort_values(by="proba_de", ascending=False)
)

# %%
top_genes = de_result_mean[de_result_mean["proba_de"] > 0.95]["gene_symbol"].tolist()

enr = gp.enrichr(
    gene_list=top_genes,
    gene_sets="KEGG_2016",
    organism="human",
    cutoff=0.05,
)

enr_results = enr.results
enr_results = enr_results[enr_results["Adjusted P-value"] < 0.05]

# %%
cols = ["Gene_set", "Term", "Adjusted P-value", "Overlap", "Genes"]
enr_results[cols]
# Out:
#      Gene_set                                               Term  \
# 0   KEGG_2016   Hematopoietic cell lineage Homo sapiens hsa04640
# 1   KEGG_2016                       Asthma Homo sapiens hsa05310
# 2   KEGG_2016  Systemic lupus erythematosus Homo sapiens hsa0...
# 3   KEGG_2016  Antigen processing and presentation Homo sapie...
# 4   KEGG_2016     Type I diabetes mellitus Homo sapiens hsa04940
# 5   KEGG_2016          Allograft rejection Homo sapiens hsa05330
# 6   KEGG_2016    Graft-versus-host disease Homo sapiens hsa05332
# 7   KEGG_2016                Leishmaniasis Homo sapiens hsa05140
# 8   KEGG_2016         Rheumatoid arthritis Homo sapiens hsa05323
# 9   KEGG_2016  Cell adhesion molecules (CAMs) Homo sapiens hs...
# 10  KEGG_2016  Staphylococcus aureus infection Homo sapiens h...
# 11  KEGG_2016  Chagas disease (American trypanosomiasis) Homo...
# 12  KEGG_2016  Intestinal immune network for IgA production H...
# 13  KEGG_2016                Toxoplasmosis Homo sapiens hsa05145
# 14  KEGG_2016            Viral myocarditis Homo sapiens hsa05416
# 15  KEGG_2016                 Tuberculosis Homo sapiens hsa05152
# 16  KEGG_2016   Autoimmune thyroid disease Homo sapiens hsa05320
# 17  KEGG_2016  Inflammatory bowel disease (IBD) Homo sapiens ...
# 18  KEGG_2016                Legionellosis Homo sapiens hsa05134
# 19  KEGG_2016  NF-kappa B signaling pathway Homo sapiens hsa0...
# 20  KEGG_2016  Glycine, serine and threonine metabolism Homo ...
# 21  KEGG_2016  Cytokine-cytokine receptor interaction Homo sa...
# 22  KEGG_2016                  Influenza A Homo sapiens hsa05164
#
#     Adjusted P-value Overlap  \
# 0       8.856816e-10   23/88
# 1       3.057882e-08   13/31
# 2       4.694366e-05  21/135
# 3       7.993099e-05   15/77
# 4       9.994987e-05   11/43
# 5       1.844425e-04   10/38
# 6       3.319980e-04   10/41
# 7       5.626977e-04   13/73
# 8       1.174379e-03   14/90
# 9       1.549616e-03  18/142
# 10      3.661271e-03   10/56
# 11      4.198833e-03  14/104
# 12      4.198833e-03    9/48
# 13      4.198833e-03  15/118
# 14      4.198833e-03   10/59
# 15      6.024122e-03  19/178
# 16      7.377039e-03    9/53
# 17      7.834961e-03   10/65
# 18      8.746399e-03    9/55
# 19      1.066015e-02   12/93
# 20      2.071894e-02    7/40
# 21      2.075320e-02  23/265
# 22      2.337097e-02  17/175
#
#                                                 Genes
# 0   HLA-DRB5;CSF1;FLT3;ITGA2B;DNTT;GP1BA;TNF;CD3D;...
# 1   IL10;HLA-DRB5;FCER1G;PRG2;RNASE3;TNF;HLA-DMB;H...
# 2   IL10;C1QA;HLA-DRB5;HIST1H3J;HIST1H4L;ACTN1;HIS...
# 3   CD74;HLA-DRB5;HSPA5;HSPA6;IFI30;TNF;CTSS;HLA-D...
# 4   HLA-DRB5;HLA-DMB;GAD1;IL1B;HLA-DPB1;GZMB;HLA-D...
# 5   IL10;HLA-DRB5;HLA-DMB;HLA-DPB1;GZMB;HLA-DRA;TN...
# 6   HLA-DRB5;HLA-DMB;IL1B;HLA-DPB1;GZMB;HLA-DRA;TN...
# 7   IL10;HLA-DRB5;NCF2;PTGS2;TNF;NFKBIA;HLA-DMB;IL...
# 8   HLA-DRB5;CSF1;CCL3L1;TNF;HLA-DMB;IL1B;CCL5;CCL...
# 9   CD274;HLA-DRB5;CD2;CLDN10;HLA-DMB;CD8B;HLA-DPB...
# 10  IL10;CFD;C1QA;HLA-DRB5;HLA-DMB;HLA-DPB1;HLA-DR...
# 11  IL10;C1QA;CCL3L1;TNF;CD3D;TGFBR1;GNAI1;NFKBIA;...
# 12  IL10;HLA-DRB5;HLA-DMB;HLA-DPB1;CXCR4;HLA-DRA;H...
# 13  IL10;HLA-DRB5;HSPA6;TNF;GNAI1;NFKBIA;CASP9;HLA...
# 14  CASP9;HLA-DRB5;CXADR;HLA-DMB;HLA-DPB1;RAC3;HLA...
# 15  IL10;CD74;HLA-DRB5;FCER1G;RIPK2;TNF;CTSS;CASP9...
# 16  IL10;HLA-DRB5;HLA-DMB;HLA-DPB1;GZMB;HLA-DRA;HL...
# 17  IL10;HLA-DRB5;HLA-DMB;IL1B;HLA-DPB1;HLA-DRA;TN...
# 18  CASP9;CLK1;NFKBIA;IL1B;HSPA6;CD14;CXCL3;CXCL2;TNF
# 19  NFKBIA;BCL2A1;GADD45B;IL1B;CCL4;BLNK;LTB;CD14;...
# 20              ALAS2;MAOA;CBS;AMT;PHGDH;ALDH7A1;GNMT
# 21  ACVR1;IL10;CCL23;CTF1;CSF1;CCL3L1;FLT3;HGF;CXC...
# 22  HLA-DRB5;HSPA6;TNFRSF10A;TNF;TMPRSS13;NFKBIA;C...

# %%
enr_results["Term"].tolist()
# Out:
# ['Hematopoietic cell lineage Homo sapiens hsa04640',
#  'Asthma Homo sapiens hsa05310',
#  'Systemic lupus erythematosus Homo sapiens hsa05322',
#  'Antigen processing and presentation Homo sapiens hsa04612',
#  'Type I diabetes mellitus Homo sapiens hsa04940',
#  'Allograft rejection Homo sapiens hsa05330',
#  'Graft-versus-host disease Homo sapiens hsa05332',
#  'Leishmaniasis Homo sapiens hsa05140',
#  'Rheumatoid arthritis Homo sapiens hsa05323',
#  'Cell adhesion molecules (CAMs) Homo sapiens hsa04514',
#  'Staphylococcus aureus infection Homo sapiens hsa05150',
#  'Chagas disease (American trypanosomiasis) Homo sapiens hsa05142',
#  'Intestinal immune network for IgA production Homo sapiens hsa04672',
#  'Toxoplasmosis Homo sapiens hsa05145',
#  'Viral myocarditis Homo sapiens hsa05416',
#  'Tuberculosis Homo sapiens hsa05152',
#  'Autoimmune thyroid disease Homo sapiens hsa05320',
#  'Inflammatory bowel disease (IBD) Homo sapiens hsa05321',
#  'Legionellosis Homo sapiens hsa05134',
#  'NF-kappa B signaling pathway Homo sapiens hsa04064',
#  'Glycine, serine and threonine metabolism Homo sapiens hsa00260',
#  'Cytokine-cytokine receptor interaction Homo sapiens hsa04060',
#  'Influenza A Homo sapiens hsa05164']

# %%
len(top_genes)
# Out:
# 892
