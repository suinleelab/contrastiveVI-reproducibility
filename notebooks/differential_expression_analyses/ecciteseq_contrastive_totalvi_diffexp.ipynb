# %%
import os
import torch

import scanpy as sc
import numpy as np
import pandas as pd
import gseapy as gp

from tqdm import tqdm
from sklearn.cluster import KMeans
from contrastive_vi.model.total_contrastive_vi import TotalContrastiveVIModel
from scripts import constants
from scvi._settings import settings
# Out:
# Global seed set to 0
# During startup - Warning messages:
# 1: package ‘methods’ was built under R version 3.6.1
# 2: package ‘datasets’ was built under R version 3.6.1
# 3: package ‘utils’ was built under R version 3.6.1
# 4: package ‘grDevices’ was built under R version 3.6.1
# 5: package ‘graphics’ was built under R version 3.6.1
# 6: package ‘stats’ was built under R version 3.6.1

# %%
settings.seed = 0
device = "cuda:7"
dataset = "papalexi_2021"
# Out:
# Global seed set to 0

# %%
split_key = constants.DATASET_SPLIT_LOOKUP[dataset]["split_key"]
background_value = constants.DATASET_SPLIT_LOOKUP[dataset]["background_value"]
seeds = constants.DEFAULT_SEEDS
latent_size = 10

# %%
adata = sc.read_h5ad(
    os.path.join(
        constants.DEFAULT_DATA_PATH,
        f"{dataset}/preprocessed/adata_top_2000_genes_tc.h5ad",
    )
)
TotalContrastiveVIModel.setup_anndata(
    adata,
    layer="count",
    protein_expression_obsm_key="protein_expression",
)
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["count"]
# INFO     Using protein expression from adata.obsm['protein_expression']
# INFO     Using protein names from columns of adata.obsm['protein_expression']
# INFO     Successfully registered anndata object containing 20729 cells, 2000 vars, 1 batches,
#          1 labels, and 4 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %%
target_indices = np.where(adata.obs[split_key] != background_value)[0]
target_adata = adata[target_indices]

# %%
genes = adata.var.index.tolist()

# %%
model_list = []
latent_rep_list = []
for seed in tqdm(seeds):
    result_dir = os.path.join(
        constants.DEFAULT_RESULTS_PATH,
        f"{dataset}/total_contrastiveVI/latent_{latent_size}",
        f"{seed}",
    )
    model_list.append(
        torch.load(
            os.path.join(result_dir, "model.ckpt"),
            map_location=device,
        ),
    )
    latent_rep_list.append(
        np.load(os.path.join(result_dir, "latent_representations.npy")),
    )
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:15<00:00,  3.02s/it]

# %%
de_result_list = []
for seed_index, seed in enumerate(seeds):
    model = model_list[seed_index]
    latent_rep = latent_rep_list[seed_index]
    latent_clusters = KMeans(n_clusters=2, random_state=123).fit(latent_rep).labels_
    cluster_label = f"cluster_{seed}"
    
    tmp_target_adata = target_adata.copy()
    tmp_target_adata.obs[cluster_label] = latent_clusters.astype(str)
    
    de_result = model.differential_expression(
        adata=tmp_target_adata,
        groupby=cluster_label,
        group1="0",
        group2="1",
        idx1=None,
        idx2=None,
        mode="change",
        delta=0.25,
        batch_size=128,
        all_stats=True,
        batch_correction=False,
        batchid1=None,
        batchid2=None,
        fdr_target=0.05,
        silent=False,
    )
    de_result["gene_symbol"] = de_result.index
    de_result["seed"] = seed
    de_result_list.append(de_result)
# Out:
# DE...: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [04:15<00:00, 255.13s/it]
# DE...: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [04:01<00:00, 241.00s/it]
# DE...: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [04:16<00:00, 256.29s/it]
# DE...: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [03:47<00:00, 227.38s/it]
# DE...: 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [04:56<00:00, 297.00s/it]

# %%
de_result_mean = (
    de_result.groupby("gene_symbol", as_index=False)
    .mean()
    .sort_values(by="proba_de", ascending=False)
)

# %%
top_genes = de_result_mean[de_result_mean["proba_de"] > 0.95]["gene_symbol"].tolist()

enr = gp.enrichr(
    gene_list=top_genes,
    gene_sets="KEGG_2016",
    organism="human",
    cutoff=0.05,
)

enr_results = enr.results
enr_results = enr_results[enr_results["Adjusted P-value"] < 0.05]

# %%
cols = ["Gene_set", "Term", "Adjusted P-value", "Overlap", "Genes"]
enr_results[cols]
# Out:
#      Gene_set                                               Term  \
# 0   KEGG_2016    Graft-versus-host disease Homo sapiens hsa05332
# 1   KEGG_2016  Staphylococcus aureus infection Homo sapiens h...
# 2   KEGG_2016          Allograft rejection Homo sapiens hsa05330
# 3   KEGG_2016     Type I diabetes mellitus Homo sapiens hsa04940
# 4   KEGG_2016  Intestinal immune network for IgA production H...
# 5   KEGG_2016   Autoimmune thyroid disease Homo sapiens hsa05320
# 6   KEGG_2016            Viral myocarditis Homo sapiens hsa05416
# 7   KEGG_2016                       Asthma Homo sapiens hsa05310
# 8   KEGG_2016  Inflammatory bowel disease (IBD) Homo sapiens ...
# 9   KEGG_2016  Antigen processing and presentation Homo sapie...
# 10  KEGG_2016  Systemic lupus erythematosus Homo sapiens hsa0...
# 11  KEGG_2016                 Tuberculosis Homo sapiens hsa05152
# 12  KEGG_2016  Cell adhesion molecules (CAMs) Homo sapiens hs...
# 13  KEGG_2016     Herpes simplex infection Homo sapiens hsa05168
# 14  KEGG_2016         Rheumatoid arthritis Homo sapiens hsa05323
# 15  KEGG_2016                Leishmaniasis Homo sapiens hsa05140
# 16  KEGG_2016                  Influenza A Homo sapiens hsa05164
# 17  KEGG_2016                    Phagosome Homo sapiens hsa04145
# 18  KEGG_2016                Toxoplasmosis Homo sapiens hsa05145
# 19  KEGG_2016  Cytokine-cytokine receptor interaction Homo sa...
# 20  KEGG_2016             HTLV-I infection Homo sapiens hsa05166
# 21  KEGG_2016  Chemokine signaling pathway Homo sapiens hsa04062
# 22  KEGG_2016  Toll-like receptor signaling pathway Homo sapi...
# 23  KEGG_2016  Epstein-Barr virus infection Homo sapiens hsa0...
# 24  KEGG_2016  Cytosolic DNA-sensing pathway Homo sapiens hsa...
# 25  KEGG_2016                    Pertussis Homo sapiens hsa05133
# 26  KEGG_2016   Hematopoietic cell lineage Homo sapiens hsa04640
# 27  KEGG_2016      African trypanosomiasis Homo sapiens hsa05143
# 28  KEGG_2016               Prion diseases Homo sapiens hsa05020
# 29  KEGG_2016  Complement and coagulation cascades Homo sapie...
# 30  KEGG_2016   Jak-STAT signaling pathway Homo sapiens hsa04630
# 31  KEGG_2016  Chagas disease (American trypanosomiasis) Homo...
#
#     Adjusted P-value Overlap  \
# 0       7.888372e-16   12/41
# 1       7.888372e-16   13/56
# 2       1.187764e-14   11/38
# 3       4.151127e-14   11/43
# 4       1.271704e-13   11/48
# 5       3.485049e-13   11/53
# 6       1.063759e-12   11/59
# 7       2.417851e-12    9/31
# 8       2.566290e-12   11/65
# 9       1.621771e-11   11/77
# 10      4.239785e-10  12/135
# 11      6.513697e-10  13/178
# 12      6.513697e-10  12/142
# 13      9.598545e-10  13/185
# 14      1.538137e-09   10/90
# 15      4.700353e-09    9/73
# 16      5.665418e-09  12/175
# 17      1.793127e-08  11/154
# 18      1.793127e-08  10/118
# 19      5.453961e-08  13/265
# 20      3.590045e-07  12/258
# 21      1.248619e-05   9/187
# 22      2.106847e-05   7/106
# 23      2.155114e-05   9/202
# 24      2.206018e-04    5/64
# 25      4.551911e-04    5/75
# 26      9.341531e-04    5/88
# 27      5.374192e-03    3/35
# 28      5.374192e-03    3/35
# 29      5.751478e-03    4/79
# 30      1.140359e-02   5/158
# 31      1.468546e-02   4/104
#
#                                                 Genes
# 0   HLA-DMA;HLA-DRB5;IL6;HLA-DMB;PRF1;HLA-DPB1;HLA...
# 1   C1QB;HLA-DRB5;CFH;C1S;HLA-DMA;HLA-DMB;HLA-DPB1...
# 2   HLA-DMA;HLA-DRB5;HLA-DMB;PRF1;HLA-DPB1;HLA-DRA...
# 3   HLA-DMA;HLA-DRB5;HLA-DMB;PRF1;HLA-DPB1;HLA-DRA...
# 4   CCL25;HLA-DMA;HLA-DRB5;IL6;HLA-DMB;HLA-DPB1;HL...
# 5   HLA-DMA;HLA-DRB5;HLA-DMB;PRF1;HLA-DPB1;HLA-DRA...
# 6   HLA-DMA;HLA-DRB5;HLA-DMB;PRF1;HLA-DPB1;HLA-DRA...
# 7   HLA-DMA;HLA-DRB5;HLA-DMB;HLA-DPB1;HLA-DRA;HLA-...
# 8   HLA-DMA;HLA-DRB5;IL6;HLA-DMB;TBX21;HLA-DPB1;HL...
# 9   CD74;HLA-DMA;HLA-DRB5;HLA-DMB;HLA-DPB1;HLA-DRA...
# 10  C1QB;HLA-DRB5;HLA-DMA;HLA-DMB;C1S;HLA-DPB1;HLA...
# 11  CD74;HLA-DRB5;IFNB1;CALML3;IL6;HLA-DMA;HLA-DMB...
# 12  CD274;HLA-DRB5;HLA-DMA;VCAM1;HLA-DMB;HLA-DPB1;...
# 13  CD74;HLA-DRB5;IFNB1;HLA-F;IL6;HLA-DMA;HLA-DMB;...
# 14  HLA-DMA;HLA-DRB5;IL6;HLA-DMB;HLA-DPB1;HLA-DRA;...
# 15  HLA-DMA;HLA-DRB5;HLA-DMB;HLA-DPB1;HLA-DRA;HLA-...
# 16  CXCL10;HLA-DRB5;IL6;HLA-DMA;HLA-DMB;IFNB1;HLA-...
# 17  HLA-DRB5;HLA-DMA;TUBA3C;HLA-DMB;HLA-DPB1;HLA-D...
# 18  HLA-DRB5;HLA-DMA;SOCS1;HLA-DMB;HLA-DPB1;HLA-DR...
# 19  CCL25;CXCL9;CCL4L1;IFNB1;CCL4L2;OSM;INHBA;CXCL...
# 20  HLA-DRB5;IL6;HLA-DMA;VCAM1;HLA-DMB;HLA-DPB1;HL...
# 21  CCL25;CXCL10;ITK;CXCL11;CXCL9;CCL8;CCL7;CCL4L1...
# 22        CXCL10;CXCL11;IL6;CXCL9;CCL4L1;IFNB1;CCL4L2
# 23  FCER2;HLA-DRB5;HLA-DPB1;HLA-DRA;HLA-F;HLA-DRB1...
# 24                     CXCL10;IL6;CCL4L1;IFNB1;CCL4L2
# 25                           C1QB;IL6;C1S;CALML3;C1QC
# 26                FCER2;HLA-DRB5;IL6;HLA-DRA;HLA-DRB1
# 27                                     IL6;VCAM1;IDO1
# 28                                      C1QB;IL6;C1QC
# 29                                  C1QB;CFH;C1S;C1QC
# 30                          IL6;IFNL1;SOCS1;IFNB1;OSM
# 31                                C1QB;IL6;IFNB1;C1QC

# %%
enr_results["Term"].tolist()
# Out:
# ['Graft-versus-host disease Homo sapiens hsa05332',
#  'Staphylococcus aureus infection Homo sapiens hsa05150',
#  'Allograft rejection Homo sapiens hsa05330',
#  'Type I diabetes mellitus Homo sapiens hsa04940',
#  'Intestinal immune network for IgA production Homo sapiens hsa04672',
#  'Autoimmune thyroid disease Homo sapiens hsa05320',
#  'Viral myocarditis Homo sapiens hsa05416',
#  'Asthma Homo sapiens hsa05310',
#  'Inflammatory bowel disease (IBD) Homo sapiens hsa05321',
#  'Antigen processing and presentation Homo sapiens hsa04612',
#  'Systemic lupus erythematosus Homo sapiens hsa05322',
#  'Tuberculosis Homo sapiens hsa05152',
#  'Cell adhesion molecules (CAMs) Homo sapiens hsa04514',
#  'Herpes simplex infection Homo sapiens hsa05168',
#  'Rheumatoid arthritis Homo sapiens hsa05323',
#  'Leishmaniasis Homo sapiens hsa05140',
#  'Influenza A Homo sapiens hsa05164',
#  'Phagosome Homo sapiens hsa04145',
#  'Toxoplasmosis Homo sapiens hsa05145',
#  'Cytokine-cytokine receptor interaction Homo sapiens hsa04060',
#  'HTLV-I infection Homo sapiens hsa05166',
#  'Chemokine signaling pathway Homo sapiens hsa04062',
#  'Toll-like receptor signaling pathway Homo sapiens hsa04620',
#  'Epstein-Barr virus infection Homo sapiens hsa05169',
#  'Cytosolic DNA-sensing pathway Homo sapiens hsa04623',
#  'Pertussis Homo sapiens hsa05133',
#  'Hematopoietic cell lineage Homo sapiens hsa04640',
#  'African trypanosomiasis Homo sapiens hsa05143',
#  'Prion diseases Homo sapiens hsa05020',
#  'Complement and coagulation cascades Homo sapiens hsa04610',
#  'Jak-STAT signaling pathway Homo sapiens hsa04630',
#  'Chagas disease (American trypanosomiasis) Homo sapiens hsa05142']

# %%
len(top_genes)
# Out:
# 122
