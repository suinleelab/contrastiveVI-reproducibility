# %%
import os
import torch

import scanpy as sc
import numpy as np
import pandas as pd
import gseapy as gp

from tqdm import tqdm
from sklearn.cluster import KMeans
from contrastive_vi.model.contrastive_vi import ContrastiveVIModel
from scripts import constants
from scvi._settings import settings
# Out:
# Global seed set to 0
# During startup - Warning messages:
# 1: package ‘methods’ was built under R version 3.6.1
# 2: package ‘datasets’ was built under R version 3.6.1
# 3: package ‘utils’ was built under R version 3.6.1
# 4: package ‘grDevices’ was built under R version 3.6.1
# 5: package ‘graphics’ was built under R version 3.6.1
# 6: package ‘stats’ was built under R version 3.6.1

# %%
settings.seed = 0
device = "cuda:1"
dataset = "mcfarland_2020"
# Out:
# Global seed set to 0

# %%
pathway_enr_fdr = 0.1

# %%
split_key = constants.DATASET_SPLIT_LOOKUP[dataset]["split_key"]
background_value = constants.DATASET_SPLIT_LOOKUP[dataset]["background_value"]
label_key = constants.DATASET_SPLIT_LOOKUP[dataset]["label_key"]
seeds = constants.DEFAULT_SEEDS
latent_size = 10

# %%
adata = sc.read_h5ad(
    os.path.join(
        constants.DEFAULT_DATA_PATH,
        f"{dataset}/preprocessed/adata_top_2000_genes_tc.h5ad",
    )
)
ContrastiveVIModel.setup_anndata(adata, layer="count")
# Out:
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["count"]
# INFO     Successfully registered anndata object containing 5928 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %%
target_indices = np.where(adata.obs[split_key] != background_value)[0]
target_adata = adata[target_indices]
background_indices = np.where(adata.obs[split_key] == background_value)[0]
background_adata = adata[background_indices]

# %%
genes = pd.read_table(
    os.path.join(
        constants.DEFAULT_DATA_PATH,
        dataset,
        "idasanutlin",
        "Idasanutlin_24hr_expt1",
        "genes.tsv",
    ),
    header=None,
)
genes = genes.rename(columns={0: "ensembl_id", 1: "gene_symbol"})
genes = genes[genes["ensembl_id"].isin(adata.var.index)]

# %%
model_list = []
latent_rep_list = []
for seed in tqdm(seeds):
    result_dir = os.path.join(
        constants.DEFAULT_RESULTS_PATH,
        f"{dataset}/contrastiveVI/latent_{latent_size}",
        f"{seed}",
    )
    model_list.append(
        torch.load(
            os.path.join(result_dir, "model.ckpt"),
            map_location=device,
        ),
    )
    latent_rep_list.append(
        np.load(os.path.join(result_dir, "latent_representations.npy")),
    )
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [01:45<00:00, 21.20s/it]

# %%
de_results = []
enr_results = []
label_proportion_results = []
assigned_label_results = []

for seed_index, seed in enumerate(seeds):
    model = model_list[seed_index]
    latent_rep = latent_rep_list[seed_index]
    latent_clusters = KMeans(n_clusters=2, random_state=123).fit(latent_rep).labels_
    cluster_label = f"cluster_{seed}"
    
    tmp_target_adata = target_adata.copy()
    tmp_target_adata.obs[cluster_label] = latent_clusters.astype(str)
    tmp_background_adata = background_adata.copy()
    tmp_background_adata.obs[cluster_label] = "background"
    
    de_results.append({})
    enr_results.append({})
    label_proportion_results.append({})
    assigned_label_results.append({})
    
    for cluster in np.unique(latent_clusters):
        cluster_str = f"{cluster}"
        
        label_proportions = (
            tmp_target_adata[tmp_target_adata.obs[cluster_label] == cluster_str]
            .obs[label_key].value_counts()
            / (tmp_target_adata.obs[cluster_label] == cluster_str).sum()
        )
        label_proportion_results[-1][cluster_str] = label_proportions
        assigned_label_results[-1][cluster_str] = (
            label_proportions.index[label_proportions.argmax()]
        )
        
        cluster_adata = tmp_background_adata.concatenate(
            tmp_target_adata[tmp_target_adata.obs[cluster_label] == cluster_str]
        )
    
        cluster_de_result = model.differential_expression(
            adata=cluster_adata,
            groupby=cluster_label,
            group1="background",
            group2=cluster_str,
            idx1=None,
            idx2=None,
            mode="change",
            delta=0.25,
            batch_size=128,
            all_stats=True,
            batch_correction=False,
            batchid1=None,
            batchid2=None,
            fdr_target=0.05,
            silent=False,
        )

        cluster_de_result.reset_index()
        cluster_de_result["ensembl_id"] = cluster_de_result.index
        cluster_de_result = cluster_de_result.merge(genes, on="ensembl_id")
        cluster_de_result["seed"] = seed
        de_results[-1][cluster_str] = cluster_de_result
        
        top_genes = cluster_de_result[
            cluster_de_result["proba_de"] > 0.95
        ]["gene_symbol"].tolist()
        enr = gp.enrichr(
            gene_list=top_genes,
            gene_sets="KEGG_2016",
            organism="human",
            cutoff=pathway_enr_fdr,
        )
        cluster_enr_result = enr.results
        cluster_enr_result = cluster_enr_result[
            cluster_enr_result["Adjusted P-value"] < pathway_enr_fdr
        ]
        enr_results[-1][cluster_str] = cluster_enr_result
# Out:
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.layers["count"]
# INFO     Registered keys:['X', 'batch_indices', 'labels']
# INFO     Successfully registered anndata object containing 3934 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# /homes/gws/clin25/miniconda3/envs/contrastive-vi-env/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function transfer_anndata_setup is deprecated; This method will be removed in 0.15.0. Please avoid building any new dependencies on it.
#   warnings.warn(msg, category=FutureWarning)
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:38<00:00, 38.61s/it]
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.layers["count"]
# INFO     Registered keys:['X', 'batch_indices', 'labels']
# INFO     Successfully registered anndata object containing 4825 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# /homes/gws/clin25/miniconda3/envs/contrastive-vi-env/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function transfer_anndata_setup is deprecated; This method will be removed in 0.15.0. Please avoid building any new dependencies on it.
#   warnings.warn(msg, category=FutureWarning)
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:39<00:00, 39.14s/it]
# 2022-01-27 14:24:37,039 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.1
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.layers["count"]
# INFO     Registered keys:['X', 'batch_indices', 'labels']
# INFO     Successfully registered anndata object containing 5205 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# /homes/gws/clin25/miniconda3/envs/contrastive-vi-env/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function transfer_anndata_setup is deprecated; This method will be removed in 0.15.0. Please avoid building any new dependencies on it.
#   warnings.warn(msg, category=FutureWarning)
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:38<00:00, 38.41s/it]
# 2022-01-27 14:25:30,900 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.1
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.layers["count"]
# INFO     Registered keys:['X', 'batch_indices', 'labels']
# INFO     Successfully registered anndata object containing 3554 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:38<00:00, 38.32s/it]
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.layers["count"]
# INFO     Registered keys:['X', 'batch_indices', 'labels']
# INFO     Successfully registered anndata object containing 3463 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# /homes/gws/clin25/miniconda3/envs/contrastive-vi-env/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function transfer_anndata_setup is deprecated; This method will be removed in 0.15.0. Please avoid building any new dependencies on it.
#   warnings.warn(msg, category=FutureWarning)
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:36<00:00, 36.23s/it]
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.layers["count"]
# INFO     Registered keys:['X', 'batch_indices', 'labels']
# INFO     Successfully registered anndata object containing 5296 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# /homes/gws/clin25/miniconda3/envs/contrastive-vi-env/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function transfer_anndata_setup is deprecated; This method will be removed in 0.15.0. Please avoid building any new dependencies on it.
#   warnings.warn(msg, category=FutureWarning)
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:37<00:00, 37.55s/it]
# 2022-01-27 14:27:44,829 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.1
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.layers["count"]
# INFO     Registered keys:['X', 'batch_indices', 'labels']
# INFO     Successfully registered anndata object containing 3507 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# /homes/gws/clin25/miniconda3/envs/contrastive-vi-env/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function transfer_anndata_setup is deprecated; This method will be removed in 0.15.0. Please avoid building any new dependencies on it.
#   warnings.warn(msg, category=FutureWarning)
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:36<00:00, 36.92s/it]
# 2022-01-27 14:28:37,069 Warning: No enrich terms using library KEGG_2016 when cutoff = 0.1
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.layers["count"]
# INFO     Registered keys:['X', 'batch_indices', 'labels']
# INFO     Successfully registered anndata object containing 5252 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:37<00:00, 37.54s/it]
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.layers["count"]
# INFO     Registered keys:['X', 'batch_indices', 'labels']
# INFO     Successfully registered anndata object containing 5089 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# /homes/gws/clin25/miniconda3/envs/contrastive-vi-env/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function transfer_anndata_setup is deprecated; This method will be removed in 0.15.0. Please avoid building any new dependencies on it.
#   warnings.warn(msg, category=FutureWarning)
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:36<00:00, 36.75s/it]
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.layers["count"]
# INFO     Registered keys:['X', 'batch_indices', 'labels']
# INFO     Successfully registered anndata object containing 3670 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# /homes/gws/clin25/miniconda3/envs/contrastive-vi-env/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function transfer_anndata_setup is deprecated; This method will be removed in 0.15.0. Please avoid building any new dependencies on it.
#   warnings.warn(msg, category=FutureWarning)
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:37<00:00, 37.33s/it]

# %%
enr_df_list = []
for i in range(len(assigned_label_results)):
    assigned_labels = assigned_label_results[i]
    enrs = enr_results[i]
    for cluster in assigned_labels.keys():
        enr = enrs[cluster].copy()
        enr["assigned_label"] = assigned_labels[cluster]
        enr["cluster"] = cluster
        enr["seed"] = constants.DEFAULT_SEEDS[i]
        enr_df_list.append(enr)
enr_df = pd.concat(enr_df_list)

# %%
cols = ["Gene_set", "Term", "Adjusted P-value", "Overlap", "Genes"]
cols += ["assigned_label", "cluster", "seed"]
enr_df = enr_df[cols]

# %% [markdown]
# ### Enriched pathways for cluster associated with idasanutlin-treated TP53 mutants vs. DMSO-treated cells.

# %%
enr_df[enr_df["assigned_label"] == "Mutation"].sort_values(by="Term", ascending=False)
# Out:
#      Gene_set                                               Term  \
# 18  KEGG_2016  Vascular smooth muscle contraction Homo sapien...
# 4   KEGG_2016  Vascular smooth muscle contraction Homo sapien...
# 2   KEGG_2016    Thyroid hormone synthesis Homo sapiens hsa04918
# 1   KEGG_2016           Salivary secretion Homo sapiens hsa04970
# 3   KEGG_2016              Renin secretion Homo sapiens hsa04924
# 0   KEGG_2016              Renin secretion Homo sapiens hsa04924
# 10  KEGG_2016        Ras signaling pathway Homo sapiens hsa04014
# 8   KEGG_2016       Rap1 signaling pathway Homo sapiens hsa04015
# 2   KEGG_2016            Phototransduction Homo sapiens hsa04744
# 2   KEGG_2016            Phototransduction Homo sapiens hsa04744
# 13  KEGG_2016  Phosphatidylinositol signaling system Homo sap...
# 1   KEGG_2016                    Pertussis Homo sapiens hsa05133
# 0   KEGG_2016                    Pertussis Homo sapiens hsa05133
# 5   KEGG_2016               Oocyte meiosis Homo sapiens hsa04114
# 20  KEGG_2016               Oocyte meiosis Homo sapiens hsa04114
# 19  KEGG_2016  Neurotrophin signaling pathway Homo sapiens hs...
# 16  KEGG_2016                Melanogenesis Homo sapiens hsa04916
# 5   KEGG_2016       Long-term potentiation Homo sapiens hsa04720
# 14  KEGG_2016  Inflammatory mediator regulation of TRP channe...
# 11  KEGG_2016       GnRH signaling pathway Homo sapiens hsa04912
# 0   KEGG_2016       Glutathione metabolism Homo sapiens hsa00480
# 17  KEGG_2016   Glucagon signaling pathway Homo sapiens hsa04922
# 4   KEGG_2016                       Glioma Homo sapiens hsa05214
# 7   KEGG_2016       Gastric acid secretion Homo sapiens hsa04971
# 15  KEGG_2016   Estrogen signaling pathway Homo sapiens hsa04915
# 3   KEGG_2016   Estrogen signaling pathway Homo sapiens hsa04915
# 21  KEGG_2016         Dopaminergic synapse Homo sapiens hsa04728
# 12  KEGG_2016        Circadian entrainment Homo sapiens hsa04713
# 1   KEGG_2016  Arachidonic acid metabolism Homo sapiens hsa00590
# 6   KEGG_2016        Amphetamine addiction Homo sapiens hsa05031
# 9   KEGG_2016  Aldosterone synthesis and secretion Homo sapie...
#
#     Adjusted P-value Overlap                  Genes assigned_label cluster  \
# 18          0.088861   2/120          CALML5;CALML3       Mutation       1
# 4           0.064789   3/120  CALML5;PLA2G2A;CALML3       Mutation       0
# 2           0.014125    1/71                   GPX3       Mutation       0
# 1           0.033661    3/89     CST1;CALML5;CALML3       Mutation       1
# 3           0.072130    2/64          CALML5;CALML3       Mutation       1
# 0           0.047842    3/64    CALML5;CLCA2;CALML3       Mutation       0
# 10          0.072130   3/227    FGF14;CALML5;CALML3       Mutation       1
# 8           0.072130   3/211    FGF14;CALML5;CALML3       Mutation       1
# 2           0.033661    2/27          CALML5;CALML3       Mutation       1
# 2           0.052900    2/27          CALML5;CALML3       Mutation       0
# 13          0.072130    2/98          CALML5;CALML3       Mutation       1
# 1           0.047842    3/75   CALML5;CALML3;SFTPA1       Mutation       0
# 0           0.033661    3/75   CALML5;CALML3;SFTPA1       Mutation       1
# 5           0.064789   3/123    CALML5;CALML3;AURKA       Mutation       0
# 20          0.088861   2/123          CALML5;CALML3       Mutation       1
# 19          0.088861   2/120          CALML5;CALML3       Mutation       1
# 16          0.072130   2/100          CALML5;CALML3       Mutation       1
# 5           0.072130    2/66          CALML5;CALML3       Mutation       1
# 14          0.072130    2/98          CALML5;CALML3       Mutation       1
# 11          0.072130    2/91          CALML5;CALML3       Mutation       1
# 0           0.014125    1/52                   GPX3       Mutation       0
# 17          0.072130   2/101          CALML5;CALML3       Mutation       1
# 4           0.072130    2/65          CALML5;CALML3       Mutation       1
# 7           0.072130    2/74          CALML5;CALML3       Mutation       1
# 15          0.072130    2/99          CALML5;CALML3       Mutation       1
# 3           0.052900    3/99    CALML5;HSPA6;CALML3       Mutation       0
# 21          0.092495   2/129          CALML5;CALML3       Mutation       1
# 12          0.072130    2/95          CALML5;CALML3       Mutation       1
# 1           0.014125    1/62                   GPX3       Mutation       0
# 6           0.072130    2/67          CALML5;CALML3       Mutation       1
# 9           0.072130    2/81          CALML5;CALML3       Mutation       1
#
#     seed
# 18    46
# 4    123
# 2    999
# 1     46
# 3     46
# 0    123
# 10    46
# 8     46
# 2     46
# 2    123
# 13    46
# 1    123
# 0     46
# 5    123
# 20    46
# 19    46
# 16    46
# 5     46
# 14    46
# 11    46
# 0    999
# 17    46
# 4     46
# 7     46
# 15    46
# 3    123
# 21    46
# 12    46
# 1    999
# 6     46
# 9     46

# %% [markdown]
# ### Enriched pathways for cluster associated with idasanutlin-treated TP53 wild-types vs. DMSO-treated cells.

# %%
enr_df[enr_df["assigned_label"] == "Wild Type"].sort_values(by="Term", ascending=False)
# Out:
#      Gene_set                                               Term  \
# 0   KEGG_2016        p53 signaling pathway Homo sapiens hsa04115
# 0   KEGG_2016        p53 signaling pathway Homo sapiens hsa04115
# 1   KEGG_2016        p53 signaling pathway Homo sapiens hsa04115
# 12  KEGG_2016         Viral carcinogenesis Homo sapiens hsa05203
# 6   KEGG_2016  Vascular smooth muscle contraction Homo sapien...
# 0   KEGG_2016  Ubiquitin mediated proteolysis Homo sapiens hs...
# 9   KEGG_2016  Transcriptional misregulation in cancer Homo s...
# 11  KEGG_2016      Proteoglycans in cancer Homo sapiens hsa05205
# 5   KEGG_2016              Prostate cancer Homo sapiens hsa05215
# 3   KEGG_2016                     Melanoma Homo sapiens hsa05218
# 2   KEGG_2016                       Glioma Homo sapiens hsa05214
# 8   KEGG_2016       FoxO signaling pathway Homo sapiens hsa04068
# 10  KEGG_2016  Epstein-Barr virus infection Homo sapiens hsa0...
# 4   KEGG_2016     Chronic myeloid leukemia Homo sapiens hsa05220
# 1   KEGG_2016                   Cell cycle Homo sapiens hsa04110
# 2   KEGG_2016                   Cell cycle Homo sapiens hsa04110
# 7   KEGG_2016                   Cell cycle Homo sapiens hsa04110
# 1   KEGG_2016               Bladder cancer Homo sapiens hsa05219
#
#     Adjusted P-value Overlap                                  Genes  \
# 0           0.001761    3/69                      CDKN1A;MDM2;GTSE1
# 0           0.001896    6/69  CDKN1A;CCNB1;TP53I3;SERPINE1;MDM2;FAS
# 1           0.022649    4/69            CDKN1A;TP53I3;SERPINE1;MDM2
# 12          0.055491   2/205                            CDKN1A;MDM2
# 6           0.034514   2/120                            ACTA2;ACTG2
# 0           0.012323   6/137   CDC20;UBE2C;UBE2S;MDM2;UBE2QL1;BIRC7
# 9           0.055491   2/180                            CDKN1A;MDM2
# 11          0.055491   2/203                            CDKN1A;MDM2
# 5           0.024131    2/89                            CDKN1A;MDM2
# 3           0.019620    2/71                            CDKN1A;MDM2
# 2           0.019620    2/65                            CDKN1A;MDM2
# 8           0.035125   2/133                            CDKN1A;MDM2
# 10          0.055491   2/202                            CDKN1A;MDM2
# 4           0.019620    2/73                            CDKN1A;MDM2
# 1           0.024844   6/124     CDC20;CCNA2;CCNB1;CDKN1A;PLK1;MDM2
# 2           0.022649   5/124           CDC20;CCNA2;CDKN1A;PLK1;MDM2
# 7           0.034514   2/124                            CDKN1A;MDM2
# 1           0.015601    2/41                            CDKN1A;MDM2
#
#    assigned_label cluster  seed
# 0       Wild Type       1   999
# 0       Wild Type       0   789
# 1       Wild Type       1    42
# 12      Wild Type       1   999
# 6       Wild Type       1   999
# 0       Wild Type       1    42
# 9       Wild Type       1   999
# 11      Wild Type       1   999
# 5       Wild Type       1   999
# 3       Wild Type       1   999
# 2       Wild Type       1   999
# 8       Wild Type       1   999
# 10      Wild Type       1   999
# 4       Wild Type       1   999
# 1       Wild Type       0   789
# 2       Wild Type       1    42
# 7       Wild Type       1   999
# 1       Wild Type       1   999
