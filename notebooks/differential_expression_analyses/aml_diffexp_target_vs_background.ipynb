# %%
import os
import torch

import scanpy as sc
import numpy as np
import pandas as pd
import gseapy as gp

from tqdm import tqdm
from sklearn.cluster import KMeans
from contrastive_vi.model.contrastive_vi import ContrastiveVIModel
from scripts import constants
from scvi._settings import settings
# Out:
# Global seed set to 0
# During startup - Warning messages:
# 1: package ‘methods’ was built under R version 3.6.1
# 2: package ‘datasets’ was built under R version 3.6.1
# 3: package ‘utils’ was built under R version 3.6.1
# 4: package ‘grDevices’ was built under R version 3.6.1
# 5: package ‘graphics’ was built under R version 3.6.1
# 6: package ‘stats’ was built under R version 3.6.1

# %%
settings.seed = 0
device = "cuda:2"
dataset = "zheng_2017"
# Out:
# Global seed set to 0

# %%
pathway_enr_fdr = 0.05
expression_delta = 0.15

# %%
split_key = constants.DATASET_SPLIT_LOOKUP[dataset]["split_key"]
background_value = constants.DATASET_SPLIT_LOOKUP[dataset]["background_value"]
label_key = constants.DATASET_SPLIT_LOOKUP[dataset]["label_key"]
seeds = constants.DEFAULT_SEEDS
latent_size = 10

# %%
adata = sc.read_h5ad(
    os.path.join(
        constants.DEFAULT_DATA_PATH,
        f"{dataset}/preprocessed/adata_top_2000_genes.h5ad",
    )
)
ContrastiveVIModel.setup_anndata(adata, layer="count")
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["count"]
# INFO     Successfully registered anndata object containing 16856 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %%
target_indices = np.where(adata.obs[split_key] != background_value)[0]
background_indices = np.where(adata.obs[split_key] == background_value)[0]

# %%
genes = pd.read_table(
    os.path.join(
        constants.DEFAULT_DATA_PATH,
        dataset,
        "aml027_post_transplant_filtered_gene_bc_matrices",
        "filtered_matrices_mex/hg19",
        "genes.tsv",
    ),
    header=None,
)
genes = genes.rename(columns={0: "ensembl_id", 1: "gene_symbol"})
genes = genes[genes["ensembl_id"].isin(adata.var.index)]

# %%
model_list = []
for seed in tqdm(seeds):
    result_dir = os.path.join(
        "/projects/leelab/contrastiveVI/results-fixed-background-size",
        f"{dataset}/contrastiveVI/latent_{latent_size}",
        f"{seed}",
    )
    model_list.append(
        torch.load(
            os.path.join(result_dir, "model.ckpt"),
            map_location=device,
        ),
    )
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:48<00:00,  9.75s/it]

# %%
de_result_list = []
enr_result_list = []

for seed_index, seed in enumerate(seeds):
    model = model_list[seed_index]
    
    de_result = model.differential_expression(
        adata=adata,
        groupby=None,
        group1=None,
        group2=None,
        idx1=background_indices,
        idx2=target_indices,
        mode="change",
        delta=expression_delta,
        batch_size=128,
        all_stats=True,
        batch_correction=False,
        batchid1=None,
        batchid2=None,
        fdr_target=0.05,
        silent=False,
        target_idx=target_indices,
    )

    de_result.reset_index()
    de_result["ensembl_id"] = de_result.index
    de_result = de_result.merge(genes, on="ensembl_id")
    de_result["seed"] = seed
    de_result_list.append(de_result)

    top_genes = de_result[de_result["proba_de"] > 0.95]["gene_symbol"].tolist()
    enr = gp.enrichr(
        gene_list=top_genes,
        gene_sets="KEGG_2016",
        organism="human",
        cutoff=pathway_enr_fdr,
    )
    enr_result = enr.results
    enr_result = enr_result[enr_result["Adjusted P-value"] < pathway_enr_fdr]
    enr_result["seed"] = seed
    enr_result_list.append(enr_result)
# Out:
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:37<00:00, 37.06s/it]
# /tmp/ipykernel_17601/2342364654.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enr_result["seed"] = seed
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:35<00:00, 35.40s/it]
# /tmp/ipykernel_17601/2342364654.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enr_result["seed"] = seed
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:36<00:00, 36.20s/it]
# /tmp/ipykernel_17601/2342364654.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enr_result["seed"] = seed
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:35<00:00, 35.61s/it]
# /tmp/ipykernel_17601/2342364654.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enr_result["seed"] = seed
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:35<00:00, 35.95s/it]
# /tmp/ipykernel_17601/2342364654.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enr_result["seed"] = seed

# %%
enr_df = pd.concat(enr_result_list)
cols = ["Gene_set", "Term", "Adjusted P-value", "Overlap", "Genes"]
cols += ["seed"]
enr_df = enr_df[cols]

# %%
enr_df
# Out:
#      Gene_set                                               Term  \
# 0   KEGG_2016  Systemic lupus erythematosus Homo sapiens hsa0...
# 1   KEGG_2016   Hematopoietic cell lineage Homo sapiens hsa04640
# 2   KEGG_2016                       Asthma Homo sapiens hsa05310
# 3   KEGG_2016  Antigen processing and presentation Homo sapie...
# 4   KEGG_2016                   Alcoholism Homo sapiens hsa05034
# ..        ...                                                ...
# 29  KEGG_2016  Epstein-Barr virus infection Homo sapiens hsa0...
# 30  KEGG_2016  Chagas disease (American trypanosomiasis) Homo...
# 31  KEGG_2016         Viral carcinogenesis Homo sapiens hsa05203
# 32  KEGG_2016                      Malaria Homo sapiens hsa05144
# 33  KEGG_2016       FoxO signaling pathway Homo sapiens hsa04068
#
#     Adjusted P-value Overlap  \
# 0       6.882865e-14  45/135
# 1       5.099962e-08   28/88
# 2       5.272066e-08   16/31
# 3       1.648756e-05   22/77
# 4       4.610281e-05  36/179
# ..               ...     ...
# 29      3.864584e-02  28/202
# 30      4.047421e-02  17/104
# 31      4.451226e-02  28/205
# 32      4.740853e-02   10/49
# 33      4.740853e-02  20/133
#
#                                                 Genes  seed
# 0   C1QA;HIST1H2BM;HIST1H2BO;HIST1H3J;HIST1H2BJ;HI...   123
# 1   GYPA;CSF1;FLT3;ITGA2B;TNF;CD3D;CD38;CD14;CD34;...   123
# 2   IL10;HLA-DRB5;FCER1G;PRG2;RNASE3;TNF;HLA-DMA;H...   123
# 3   CD74;HLA-DRB5;HSPA5;HSPA6;IFI30;TNF;CTSS;HLA-D...   123
# 4   HIST1H2BM;HIST1H2BO;HIST1H3J;HIST1H2BJ;MAOA;HI...   123
# ..                                                ...   ...
# 29  CDKN1A;PIK3R5;MAPK8;MYC;AKT3;CD38;RIPK1;PLCG1;...   999
# 30  IL10;C1QA;JUN;CCL3L1;TNF;CD3D;TGFBR1;GNAI1;PIK...   999
# 31  GTF2A1;HIST1H2BM;CDKN1A;HIST1H2BO;HIST1H2BJ;HI...   999
# 32   IL10;GYPA;KLRB1;CD81;GYPB;HGF;IL1B;CD36;HBA1;TNF   999
# 33  IL10;CDKN1A;GADD45B;PRMT1;PLK2;PLK1;SETD7;PRKA...   999
#
# [150 rows x 6 columns]

# %% [markdown]
# ## Aggregate analysis

# %%
de_result = pd.concat(de_result_list)
de_result_mean = (
    de_result.groupby("gene_symbol", as_index=False)
    .mean()
    .sort_values(by="proba_de", ascending=False)
)

# %%
de_result_mean["proba_de"].describe()
# Out:
# count    2000.000000
# mean        0.963476
# std         0.014507
# min         0.892560
# 25%         0.956230
# 50%         0.966480
# 75%         0.974170
# max         0.987760
# Name: proba_de, dtype: float64

# %%
top_genes = de_result_mean[de_result_mean["proba_de"] > 0.95]["gene_symbol"].tolist()

# 5   HLA-DRB5;GAD1;ICA1;GZMB;TNF;HLA-DMA;HLA-DMB;IL...
# 6   HIST1H2BM;HIST1H2BO;HIST1H3J;HIST1H2BJ;MAOA;HI...
# 7   HLA-DRB5;GZMB;TNF;HLA-DMA;HLA-DMB;IL1B;HLA-DPB...
# 8   IL10;JUN;MARCKSL1;HLA-DRB5;NCF2;PTGS2;TNF;NFKB...
# 9   IL10;HLA-DRB5;GZMB;TNF;HLA-DMA;HLA-DMB;HLA-DPB...
# 10  TNF;PIK3R5;CASP9;SOCS3;MAPK8;HLA-DMA;HLA-DMB;C...
# 11  IL10;HLA-DRB5;IL15;CXCR4;TNFSF13B;HLA-DMA;HLA-...
# 12  CDKN1A;CRTC1;CD3D;TNF;PIK3R5;CDC20;CCNB2;HLA-D...
# 13  IL10;HLA-DRB5;HSPA6;TNF;GNAI1;PIK3R5;NFKBIA;CA...
# 14  IFIT1;CFP;TNF;SOCS3;MAPK8;HLA-DMA;HLA-DMB;CCL5...
# 15  IL10;CFD;C1QA;HLA-DRB5;FPR1;HLA-DMA;HLA-DMB;HL...
# 16  BCL2A1;GADD45B;IL1R1;DDX58;PTGS2;CXCL2;TNF;TNF...
# 17  ALDH3A2;ARG2;ALDH2;ARG1;MAOA;P4HA2;CARNS1;PYCR...
# 18  IL10;JUN;HLA-DRB5;TNF;HLA-DMA;HLA-DMB;IL1B;HLA...
# 19  GTF2A1;HIST1H2BM;CDKN1A;HIST1H2BO;HIST1H2BJ;HI...
# 20  HLA-DRB5;CXADR;CASP9;HLA-DMA;HLA-DMB;HLA-DPB1;...
# 21  IL10;HLA-DMA;HLA-DRB5;HLA-DMB;HLA-DPB1;GZMB;HL...
# 22  JUN;GADD45B;BCL2A1;GZMB;TNFRSF10A;CTSW;TNF;CTS...
# 23  JUN;CSF1;NCF2;IL1R1;SIRPG;FHL2;NFATC2;MITF;TNF...
# 24  CD274;HLA-DRB5;CD2;CLDN10;HLA-DMA;HLA-DMB;CD8B...
# 25  CDKN1A;HIST1H3J;HPGD;BCL2A1;FLT3;MPO;HOXA9;HHE...
# 26       CD79A;CD8B;IGLL1;CD8A;BLNK;IL7R;CD3D;ADA;UNG
# 27  PRPS2;TKTL1;ARG2;ARG1;PYCR1;GPT;ENO2;CBS;PSAT1...
# 28  IL10;CDKN1A;GADD45B;PRMT1;PLK2;PLK1;SETD7;PRKA...
# 29  CDKN1A;RRM2;GADD45B;CASP9;CCNB2;CCND2;CDK6;CCN...
# 30  CASP9;MAPK8;JUN;APC;MYC;AKT3;LEF1;RAC3;BIRC5;T...
# 31  ITGA2B;PTGS2;PIK3R5;CASP9;NFKBIA;CDK6;CCNE2;CC...
# 32  IL10;C1QA;JUN;CCL3L1;TNF;CD3D;TGFBR1;GNAI1;PIK...
# 33  CDKN1A;PIK3R5;MAPK8;MYC;AKT3;CD38;RIPK1;PLCG1;...

# %%
len(top_genes)
# Out:
# 1682

# %% [markdown]
# Systemic lupus erythematosus is related to AML (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6078549/)
